# %% [markdown]
# **ACORN Integrated Clinical AMR Virtual Informatics Course - Module 4: Typing**
#
# # **Installation & Data Downloading**
#
# Welcome to the practical session of module **Typing**, we will start slowy with install necessary tools and download the data.
#
# We use `conda` as a package managemer and environment manager for installed software for bioinformatic. For more information, you can follow [this link](https://docs.conda.io/en/latest/). `Miniforge` is used as a mini installation and a quicker environment solver comparing to `conda`.
#
# Firstly, we install `miniforge` via python

# %%
# install mamba via pip
# !pip install -q condacolab
# import conda into python environment
import condacolab
# start installing conda
condacolab.install()

# %% [markdown]
# Checking whether conda is installed succesfully.

# %%
# !mamba
# !conda

# %% [markdown]
# Note that we are installing `conda` via Python environment in Google Collab. If you need install `conda` directly in Linux, you can follow these steps:

# %% [markdown]
# ```
# ## You should not run these codes below as these for installing conda in Linux, try these in your Linux system
# # Download Miniforge
# wget https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# # Install Miniforge
# bash Miniforge-Linux-x86_64.sh
# ```

# %% [markdown]
# Before installing tools, we need to configure the `conda` channels. Each channel is a container for different tools so we need to add `bioconda` and `conda-forge` into the channel list.

# %%
# add conda-forge channel
# !conda config --add channels conda-forge
# add bioconda channel
# !conda config --add channels bioconda
# check the list of conda channels
# !conda config --show channels
# !mamba info

# %%
# Download dataset
# !wget https://wcs_data_transfer.cog.sanger.ac.uk/typing10may.zip
# unzip the file
# !unzip typing10may.zip

# %% [markdown]
# # **BLAST - Basic Local Alignment Search Tool**
#
# In this section, we learn more about `BLAST` and how we use it.
#
# Let's start with download [the file from GitHub](https://github.com/WCSCourses/ACORN-ClinAMR/blob/main/course_data/30_May_Day_4/sequence.fasta) to your computer. In the mean time, you can go to [BLAST website of NCBI](https://blast.ncbi.nlm.nih.gov/Blast.cgi?PROGRAM=blastn&PAGE_TYPE=BlastSearch&LINK_LOC=blasthome).
#
# After downloading the file, you can upload into BLAST then run.
# <a href="https://ibb.co/KVFgWC1"><img src="https://i.ibb.co/xzJb6V4/Screenshot-2024-05-13-at-11-40-37.png" alt="Screenshot-2024-05-13-at-11-40-37" border="0"></a>
#
# What do you think about the result ?
# 1. The max score/total score
# 2. The E value
# 3. The Precentage identity

# %% [markdown]
# Please input your answer here:
#
#
# 1.
# 2.
# 3.

# %% [markdown]
# Now we edit the download sequence file (open it in text editor, or copy then edit it on NCBI panel) by remove, change and add nucleotide (please suit yourself). Then we copy and paste into BLAST again to see the result.
#
# What changes do you observe ?

# %% [markdown]
# Please input your answer here

# %% [markdown]
# # **Typing - MLST**
#
# Typing module requires `MLST` and `abricate` to run MLST and AMR typing. We will create each enviroment for each software to avoid conflicts.
# We start with `MLST` first. You can find more information about [this tool](https://github.com/tseemann/mlst).

# %%
#!mamba create -n mlst -c bioconda -c conda-forge mlst
# !mamba install -c bioconda -c conda-forge mlst

# %%
# check the list of database
# !mlst --list
# !mlst --help

# %%
# run mlst without specify the target pathogen
# !mlst <path to your data folder>/*

# %% [markdown]
# From what you saw, which species are our samples ? Have you noted that other species's housekeeping genes were also found ?
# Please input your answer here

# %%
# run mlst with specified species and save it into a tab file
# !mlst typing/*  --scheme <your scheme> >  > <your output file name>.tab
# summary the result
# !mlst --summary <your output file name>.tab > summary.tab

# %%
# read the output file
# !cat summary.tab

# %% [markdown]
# To understand more about the result, please check the table below
# ![Screenshot 2024-05-13 at 11.03.58.png](data:image/png;base64,...)

# %% [markdown]
# Do you find anything from our data ? is there anything need to be noted ?
#
# What is the dominance Sequence Type (ST) in our sample ?

# %% [markdown]
# Please input your answer here:

# %% [markdown]
# Let's move to the website www.pubmlst.org to investigate more on our ST. PubMLST is a database for MLST for various of species, you can look at the ST profile or even the geographical distribution of certain STs.
#
# Let's go to [this database](https://pubmlst.org/bigsdb?db=pubmlst_escherichia_isolates&page=query&genomes=1) then start researching.
#
# You will note that there are several tabs on the top right conner of the website, click over the `Modify Form` then add `Allele designations/scheme field values` (the plus buttom) to our form.
#
# Now search `ST (MLST (Achtman))` shceme on the left panel of newly appear part. Input the ST you want to investigate into the right pannel.
#
# Now start questionning:
# * How many sample we have with the identical ST ?
# * Their distribution geographically ?
# * The time range they have been circulating ?
# * The source of those ST ?
# * Do our samples have any connection with those samples ???
#
# What can you concluded from these results ?

# %% [markdown]
# Please input your answer here:
# Your ST:
# Result from PubMLST
# *
# *
# *
# *
# *
#
# Your conclusion:

# %% [markdown]
# # AntiMicrobial Resistant (AMR) Gene Finder
#
# In this section, we use `abricate` software from Torten Seeman. You can find more information via [this link](https://github.com/tseemann/abricate).

# %%
#Again we have to install abricate first
# !mamba install -c bioconda -c conda-forge abricate
# Out:
# Looking for: ['abricate']
#
# [+] 0.0s
# [+] 0.1s
# bioconda/linux-64 ..  ⣾  bioconda/linux-64 (check zst)
# [+] 0.0s
# bioconda/noarch (c..  ⣾  bioconda/noarch (check zst)
# [+] 0.0s
# bioconda/linux-64  ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.2s
# conda-forge/linux-64   6%
# conda-forge/noarch     1%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.3s
# conda-forge/linux-64  11%
# conda-forge/noarch    14%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.4s
# conda-forge/linux-64  15%
# conda-forge/noarch    26%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.5s
# conda-forge/linux-64  18%
# conda-forge/noarch    46%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.6s
# conda-forge/linux-64  23%
# conda-forge/noarch    46%
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾  [+] 0.7s
# conda-forge/linux-64  23%
# conda-forge/noarch    58%
# ...

# %%
#Check whether abricate working or not
# !abricate --help
# Out:
# SYNOPSIS
#   Find and collate amplicons in assembled contigs
# AUTHOR
#   Torsten Seemann (@torstenseemann)
# USAGE
#   % abricate --list
#   % abricate [options] <contigs.{fasta,gbk,embl}[.gz] ...> > out.tab
#   % abricate [options] --fofn fileOfFilenames.txt > out.tab
#   % abricate --summary <out1.tab> <out2.tab> <out3.tab> ... > summary.tab
# GENERAL
#   --help          This help.
#   --debug         Verbose debug output.
#   --quiet         Quiet mode, no stderr output.
#   --version       Print version and exit.
#   --check         Check dependencies are installed.
#   --threads [N]   Use this many BLAST+ threads [1].
#   --fofn [X]      Run on files listed in this file [].
# DATABASES
#   --setupdb       Format all the BLAST databases.
#   --list          List included databases.
#   --datadir [X]   Databases folder [/usr/local/db].
#   --db [X]        Database to use [ncbi].
# OUTPUT
#   --noheader      Suppress column header row.
# ...

# %% [markdown]
# `abricate` and `mlst` were built by Torten Seeman and both use `blastn` as the search engine so the syntax of them are similar. One thing we should note about `abricate` is the database you use for AMR gene finder. Reflexing from the lecture, let's see which data we have in `abricate`

# %%
# check the list of antimicrobial resistant gene database
# !abricate --list

# %% [markdown]
# Let's run with our data

# %%
# find AMR gene with your selected database then save the result into a csv file
# !abricate typing/* --db <your chosen reference database>  -t 2 > amr.tab

# %%
# you can have a nice summary of the result as well
# !abricate --summary amr.tab > summary.tab

# %%
# !cat summary.tab

# %% [markdown]
# What is the most common amr gene you found ?
# Let's take a look deeper into that gene via [CARD database](https://card.mcmaster.ca/), please enter your AMR gene name into the search tab of CARD website (for example mcr-1, oxa-48, etc.)
#
# With the matched result, please find:
# 1. Antibiotic Class
# 2. Mechanism of antibiotic resistance
# 3. Which Species have this AMR gene
# 4. The prevalence of this gene in our species
#
# Then the final question, is it possible that our samples have this gene ? If yes, how does it obtain it ?
#
# **!! you should also search for literature review on this**

# %% [markdown]
# Please input your answer here
